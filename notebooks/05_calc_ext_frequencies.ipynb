# %%
# %load_ext autoreload
# %autoreload 2
    
import os
import sys
import xarray as xr
import pandas as pd
import netCDF4 as nc
import numpy as np
from dask.distributed import Client
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

sys.path.append('/home/563/sc1326/repos/cdrmip_extremes')
from cdrmip_extremes.configs import data_dir, models, expts
from cdrmip_extremes import load_data
from cdrmip_extremes import ext_freq
from cdrmip_extremes.plotting import plot_extremes
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
client = Client(memory_limit=None,threads_per_worker=1,n_workers=28)

# %% [markdown]
# ### Load temperature data ###

# %%
tas_data = load_data.load_raw_tas()

# %% [markdown]
# ### Load thresholds ###

# %%
thresholds = load_data.load_threshold_data()

# %% [markdown]
# ### Load monthly extreme data (e.g. month of maximum temperature ###

# %%
thresholds
# Out:
# {'ACCESS-ESM1-5': {'heat_thresholds': <xarray.Dataset> Size: 197kB
#   Dimensions:     (lon: 180, lat: 90)
#   Coordinates:
#     * lon         (lon) float64 1kB 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
#     * lat         (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#       extrema     <U3 12B ...
#   Data variables:
#       threshold1  (lat, lon) float32 65kB ...
#       threshold2  (lat, lon) float32 65kB ...
#       threshold3  (lat, lon) float32 65kB ...,
#   'cold_thresholds': <xarray.Dataset> Size: 197kB
#   Dimensions:     (lon: 180, lat: 90)
#   Coordinates:
#     * lon         (lon) float64 1kB 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
#     * lat         (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#       extrema     <U3 12B ...
#   Data variables:
#       threshold1  (lat, lon) float32 65kB ...
#       threshold2  (lat, lon) float32 65kB ...
#       threshold3  (lat, lon) float32 65kB ...},
#  'CanESM5': {'heat_thresholds': <xarray.Dataset> Size: 197kB
#   Dimensions:     (lon: 180, lat: 90)
#   Coordinates:
#     * lon         (lon) float64 1kB 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
#     * lat         (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#       extrema     <U3 12B ...
#   Data variables:
#       threshold1  (lat, lon) float32 65kB ...
#       threshold2  (lat, lon) float32 65kB ...
#       threshold3  (lat, lon) float32 65kB ...,
#   'cold_thresholds': <xarray.Dataset> Size: 197kB
#   Dimensions:     (lon: 180, lat: 90)
#   Coordinates:
#     * lon         (lon) float64 1kB 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
#     * lat         (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#       extrema     <U3 12B ...
#   Data variables:
#       threshold1  (lat, lon) float32 65kB ...
#       threshold2  (lat, lon) float32 65kB ...
#       threshold3  (lat, lon) float32 65kB ...},
#  'CESM2': {'heat_thresholds': <xarray.Dataset> Size: 197kB
#   Dimensions:     (lon: 180, lat: 90)
#   Coordinates:
#     * lon         (lon) float64 1kB 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
#     * lat         (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#       extrema     <U3 12B ...
#   Data variables:
#       threshold1  (lat, lon) float32 65kB ...
#       threshold2  (lat, lon) float32 65kB ...
#       threshold3  (lat, lon) float32 65kB ...,
#   'cold_thresholds': <xarray.Dataset> Size: 197kB
#   Dimensions:     (lon: 180, lat: 90)
#   Coordinates:
#     * lon         (lon) float64 1kB 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
#     * lat         (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#       extrema     <U3 12B ...
#   Data variables:
#       threshold1  (lat, lon) float32 65kB ...
#       threshold2  (lat, lon) float32 65kB ...
#       threshold3  (lat, lon) float32 65kB ...},
#  'CNRM-ESM2-1': {'heat_thresholds': <xarray.Dataset> Size: 197kB
#   Dimensions:     (lon: 180, lat: 90)
#   Coordinates:
#     * lon         (lon) float64 1kB 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
#     * lat         (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#       extrema     <U3 12B ...
#   Data variables:
#       threshold1  (lat, lon) float32 65kB ...
#       threshold2  (lat, lon) float32 65kB ...
#       threshold3  (lat, lon) float32 65kB ...,
#   'cold_thresholds': <xarray.Dataset> Size: 197kB
#   Dimensions:     (lon: 180, lat: 90)
#   Coordinates:
#     * lon         (lon) float64 1kB 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
#     * lat         (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#       extrema     <U3 12B ...
#   Data variables:
#       threshold1  (lat, lon) float32 65kB ...
#       threshold2  (lat, lon) float32 65kB ...
#       threshold3  (lat, lon) float32 65kB ...},
#  'GFDL-ESM4': {'heat_thresholds': <xarray.Dataset> Size: 197kB
#   Dimensions:     (lon: 180, lat: 90)
#   Coordinates:
#     * lon         (lon) float64 1kB 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
#     * lat         (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#       extrema     <U3 12B ...
#   Data variables:
#       threshold1  (lat, lon) float32 65kB ...
#       threshold2  (lat, lon) float32 65kB ...
#       threshold3  (lat, lon) float32 65kB ...,
#   'cold_thresholds': <xarray.Dataset> Size: 197kB
#   Dimensions:     (lon: 180, lat: 90)
#   Coordinates:
#     * lon         (lon) float64 1kB 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
#     * lat         (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#       extrema     <U3 12B ...
#   Data variables:
#       threshold1  (lat, lon) float32 65kB ...
#       threshold2  (lat, lon) float32 65kB ...
#       threshold3  (lat, lon) float32 65kB ...},
#  'MIROC-ES2L': {'heat_thresholds': <xarray.Dataset> Size: 197kB
#   Dimensions:     (lon: 180, lat: 90)
#   Coordinates:
#     * lon         (lon) float64 1kB 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
#     * lat         (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#       extrema     <U3 12B ...
#   Data variables:
#       threshold1  (lat, lon) float32 65kB ...
#       threshold2  (lat, lon) float32 65kB ...
#       threshold3  (lat, lon) float32 65kB ...,
#   'cold_thresholds': <xarray.Dataset> Size: 197kB
#   Dimensions:     (lon: 180, lat: 90)
#   Coordinates:
#     * lon         (lon) float64 1kB 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
#     * lat         (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#       extrema     <U3 12B ...
#   Data variables:
#       threshold1  (lat, lon) float32 65kB ...
#       threshold2  (lat, lon) float32 65kB ...
#       threshold3  (lat, lon) float32 65kB ...},
#  'NorESM2-LM': {'heat_thresholds': <xarray.Dataset> Size: 197kB
#   Dimensions:     (lon: 180, lat: 90)
#   Coordinates:
#     * lon         (lon) float64 1kB 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
#     * lat         (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#       extrema     <U3 12B ...
#   Data variables:
#       threshold1  (lat, lon) float32 65kB ...
#       threshold2  (lat, lon) float32 65kB ...
#       threshold3  (lat, lon) float32 65kB ...,
#   'cold_thresholds': <xarray.Dataset> Size: 197kB
#   Dimensions:     (lon: 180, lat: 90)
#   Coordinates:
#     * lon         (lon) float64 1kB 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
#     * lat         (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#       extrema     <U3 12B ...
#   Data variables:
#       threshold1  (lat, lon) float32 65kB ...
#       threshold2  (lat, lon) float32 65kB ...
#       threshold3  (lat, lon) float32 65kB ...},
#  'UKESM1-0-LL': {'heat_thresholds': <xarray.Dataset> Size: 197kB
#   Dimensions:     (lon: 180, lat: 90)
#   Coordinates:
#     * lon         (lon) float64 1kB 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
#     * lat         (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#       extrema     <U3 12B ...
#   Data variables:
#       threshold1  (lat, lon) float32 65kB ...
#       threshold2  (lat, lon) float32 65kB ...
#       threshold3  (lat, lon) float32 65kB ...,
#   'cold_thresholds': <xarray.Dataset> Size: 197kB
#   Dimensions:     (lon: 180, lat: 90)
#   Coordinates:
#     * lon         (lon) float64 1kB 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
#     * lat         (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#       extrema     <U3 12B ...
#   Data variables:
#       threshold1  (lat, lon) float32 65kB ...
#       threshold2  (lat, lon) float32 65kB ...
#       threshold3  (lat, lon) float32 65kB ...}}

# %%
tas_data
# Out:
# [autoreload of cdrmip_extremes.ext_freq failed: Traceback (most recent call last):
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.08/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 276, in check
#     superreload(m, reload, self.old_objects)
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.08/lib/python3.11/site-packages/IPython/extensions/autoreload.py", line 475, in superreload
#     module = reload(module)
#              ^^^^^^^^^^^^^^
#   File "/g/data/xp65/public/apps/med_conda/envs/analysis3-25.08/lib/python3.11/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 621, in _exec
#   File "<frozen importlib._bootstrap_external>", line 936, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 1074, in get_code
#   File "<frozen importlib._bootstrap_external>", line 1004, in source_to_code
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/home/563/sc1326/repos/cdrmip_extremes/cdrmip_extremes/ext_freq.py", line 87
#     if ext_type = 'heat':
#        ^^^^^^^^^^^^^^^^^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?
# ]
# {'ACCESS-ESM1-5': {'1pctCO2': <xarray.Dataset> Size: 117MB
#   Dimensions:    (time: 1800, bnds: 2, lon: 180, lat: 90)
#   Coordinates:
#     * time       (time) object 14kB 0101-01-16 12:00:00 ... 0250-12-16 12:00:00
#     * lon        (lon) float64 1kB 0.0 2.0 4.0 6.0 8.0 ... 352.0 354.0 356.0 358.0
#     * lat        (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#   Dimensions without coordinates: bnds
#   Data variables:
#       time_bnds  (time, bnds) object 29kB ...
#       tas        (time, lat, lon) float32 117MB ...
#   Attributes: (12/49)
#       CDI:                    Climate Data Interface version 2.0.5 (https://mpi...
#       source:                 ACCESS-ESM1.5 (2019): \naerosol: CLASSIC (v1.0)\n...
#       institution:            Commonwealth Scientific and Industrial Research O...
#       Conventions:            CF-1.7 CMIP-6.2
#       activity_id:            CMIP
#       branch_method:          standard
#       ...                     ...
#       variant_label:          r1i1p1f1
#       version:                v20191115
#       cmor_version:           3.4.0
#       tracking_id:            hdl:21.14100/b3f4469e-2417-4123-bfb9-ef2cc8415cdd
#       license:                CMIP6 model data produced by CSIRO is licensed un...
#       CDO:                    Climate Data Operators version 2.0.5 (https://mpi...,
#   '1pctCO2-cdr': <xarray.Dataset> Size: 498MB
#   Dimensions:    (time: 7680, bnds: 2, lon: 180, lat: 90)
#   Coordinates:
#     * time       (time) object 61kB 0241-01-16 12:00:00 ... 0880-12-16 12:00:00
#     * lon        (lon) float64 1kB 0.0 2.0 4.0 6.0 8.0 ... 352.0 354.0 356.0 358.0
#     * lat        (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#   Dimensions without coordinates: bnds
#   Data variables:
#       time_bnds  (time, bnds) object 123kB ...
#       tas        (time, lat, lon) float32 498MB ...
#   Attributes: (12/49)
#       CDI:                    Climate Data Interface version 2.0.5 (https://mpi...
#       source:                 ACCESS-ESM1.5 (2019): \naerosol: CLASSIC (v1.0)\n...
#       institution:            Commonwealth Scientific and Industrial Research O...
#       Conventions:            CF-1.7 CMIP-6.2
#       activity_id:            CDRMIP
#       branch_method:          standard
#       ...                     ...
#       variant_label:          r1i1p1f1
#       version:                v20191118
#       cmor_version:           3.4.0
#       tracking_id:            hdl:21.14100/4de45aa2-33b7-4580-9544-ea732c1d84ee
#       license:                CMIP6 model data produced by CSIRO is licensed un...
#       CDO:                    Climate Data Operators version 2.0.5 (https://mpi...,
#   'piControl': <xarray.Dataset> Size: 389MB
#   Dimensions:    (time: 6000, bnds: 2, lon: 180, lat: 90)
#   Coordinates:
#     * time       (time) object 48kB 0271-01-16 12:00:00 ... 0770-12-16 12:00:00
#     * lon        (lon) float64 1kB 0.0 2.0 4.0 6.0 8.0 ... 352.0 354.0 356.0 358.0
#     * lat        (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#   Dimensions without coordinates: bnds
#   Data variables:
#       time_bnds  (time, bnds) object 96kB ...
#       tas        (time, lat, lon) float32 389MB ...
#   Attributes: (12/49)
#       CDI:                    Climate Data Interface version 2.0.5 (https://mpi...
#       source:                 ACCESS-ESM1.5 (2019): \naerosol: CLASSIC (v1.0)\n...
#       institution:            Commonwealth Scientific and Industrial Research O...
#       Conventions:            CF-1.7 CMIP-6.2
#       activity_id:            CMIP
#       branch_method:          standard
#       ...                     ...
#       variant_label:          r1i1p1f1
#       version:                v20191115
#       cmor_version:           3.4.0
#       tracking_id:            hdl:21.14100/3ca35d5c-2d6d-4485-bab7-2e9b7356d235
#       license:                CMIP6 model data produced by CSIRO is licensed un...
#       CDO:                    Climate Data Operators version 2.0.5 (https://mpi...},
#  'CanESM5': {'1pctCO2': <xarray.Dataset> Size: 117MB
#   Dimensions:    (time: 1812, bnds: 2, lon: 180, lat: 90)
#   Coordinates:
#     * time       (time) object 14kB 1850-01-16 12:00:00 ... 2000-12-16 12:00:00
#     * lon        (lon) float64 1kB 0.0 2.0 4.0 6.0 8.0 ... 352.0 354.0 356.0 358.0
#     * lat        (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#   Dimensions without coordinates: bnds
#   Data variables:
#       time_bnds  (time, bnds) object 29kB ...
#       tas        (time, lat, lon) float32 117MB ...
#   Attributes: (12/55)
#       CDI:                         Climate Data Interface version 2.0.5 (https:...
#       source:                      CanESM5 (2019): \naerosol: interactive\natmo...
#       institution:                 Canadian Centre for Climate Modelling and An...
#       Conventions:                 CF-1.7 CMIP-6.2
#       CCCma_model_hash:            8ac7a3c953a92eb65289508ded4d1b280d2bae9e
#       CCCma_parent_runid:          p2-pictrl
#       ...                          ...
#       variable_id:                 tas
#       variant_label:               r1i1p2f1
#       version:                     v20190429
#       license:                     CMIP6 model data produced by The Government ...
#       cmor_version:                3.4.0
#       CDO:                         Climate Data Operators version 2.0.5 (https:...,
#   '1pctCO2-cdr': <xarray.Dataset> Size: 233MB
#   Dimensions:    (time: 3600, bnds: 2, lon: 180, lat: 90)
#   Coordinates:
#     * time       (time) object 29kB 1991-01-16 12:00:00 ... 2290-12-16 12:00:00
#     * lon        (lon) float64 1kB 0.0 2.0 4.0 6.0 8.0 ... 352.0 354.0 356.0 358.0
#     * lat        (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#   Dimensions without coordinates: bnds
#   Data variables:
#       time_bnds  (time, bnds) object 58kB ...
#       tas        (time, lat, lon) float32 233MB ...
#   Attributes: (12/55)
#       CDI:                         Climate Data Interface version 2.0.5 (https:...
#       source:                      CanESM5 (2019): \naerosol: interactive\natmo...
#       institution:                 Canadian Centre for Climate Modelling and An...
#       Conventions:                 CF-1.7 CMIP-6.2
#       CCCma_model_hash:            Unknown
#       CCCma_parent_runid:          p2-1ppy
#       ...                          ...
#       variable_id:                 tas
#       variant_label:               r1i1p2f1
#       version:                     v20190429
#       license:                     CMIP6 model data produced by The Government ...
#       cmor_version:                3.4.0
#       CDO:                         Climate Data Operators version 2.0.5 (https:...,
#   'piControl': <xarray.Dataset> Size: 778MB
#   Dimensions:    (time: 12000, bnds: 2, lon: 180, lat: 90)
#   Coordinates:
#     * time       (time) object 96kB 5201-01-16 12:00:00 ... 6200-12-16 12:00:00
#     * lon        (lon) float64 1kB 0.0 2.0 4.0 6.0 8.0 ... 352.0 354.0 356.0 358.0
#     * lat        (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#   Dimensions without coordinates: bnds
#   Data variables:
#       time_bnds  (time, bnds) object 192kB ...
#       tas        (time, lat, lon) float32 778MB ...
#   Attributes: (12/55)
#       CDI:                         Climate Data Interface version 2.0.5 (https:...
#       source:                      CanESM5 (2019): \naerosol: interactive\natmo...
#       institution:                 Canadian Centre for Climate Modelling and An...
#       Conventions:                 CF-1.7 CMIP-6.2
#       CCCma_model_hash:            24718c8346665b218729640ffe79d263b76456c4
#       CCCma_parent_runid:          rc3-pictrl
#       ...                          ...
#       variable_id:                 tas
#       variant_label:               r1i1p1f1
#       version:                     v20190429
#       license:                     CMIP6 model data produced by The Government ...
#       cmor_version:                3.4.0
#       CDO:                         Climate Data Operators version 2.0.5 (https:...},
#  'CESM2': {'1pctCO2': <xarray.Dataset> Size: 117MB
#   Dimensions:    (time: 1800, bnds: 2, lon: 180, lat: 90)
#   Coordinates:
#     * time       (time) object 14kB 0001-01-15 12:00:00 ... 0150-12-15 12:00:00
#     * lon        (lon) float64 1kB 0.0 2.0 4.0 6.0 8.0 ... 352.0 354.0 356.0 358.0
#     * lat        (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#   Dimensions without coordinates: bnds
#   Data variables:
#       time_bnds  (time, bnds) object 29kB ...
#       tas        (time, lat, lon) float32 117MB ...
#   Attributes: (12/44)
#       CDI:                    Climate Data Interface version 2.0.5 (https://mpi...
#       source:                 CESM2 (2017): atmosphere: CAM6 (0.9x1.25 finite v...
#       institution:            National Center for Atmospheric Research, Climate...
#       Conventions:            CF-1.7 CMIP-6.2
#       activity_id:            CMIP
#       branch_method:          standard
#       ...                     ...
#       tracking_id:            hdl:21.14100/36ba4513-402b-49cf-9d9e-307063ee94f8
#       variable_id:            tas
#       variant_info:           CMIP6 CESM2 1pctCO2 experiment with interactive a...
#       variant_label:          r1i1p1f1
#       history:                Fri Aug 04 16:32:31 2023: cdo -remapbil,r180x90 N...
#       CDO:                    Climate Data Operators version 2.0.5 (https://mpi...,
#   '1pctCO2-cdr': <xarray.Dataset> Size: 156MB
#   Dimensions:    (time: 2400, bnds: 2, lon: 180, lat: 90)
#   Coordinates:
#     * time       (time) object 19kB 0001-01-15 12:00:00 ... 0200-12-15 12:00:00
#     * lon        (lon) float64 1kB 0.0 2.0 4.0 6.0 8.0 ... 352.0 354.0 356.0 358.0
#     * lat        (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#   Dimensions without coordinates: bnds
#   Data variables:
#       time_bnds  (time, bnds) object 38kB ...
#       tas        (time, lat, lon) float32 156MB ...
#   Attributes: (12/44)
#       CDI:                    Climate Data Interface version 2.0.5 (https://mpi...
#       source:                 CESM2 (2017): atmosphere: CAM6 (0.9x1.25 finite v...
#       institution:            National Center for Atmospheric Research, Climate...
#       Conventions:            CF-1.7 CMIP-6.2
#       activity_id:            CDRMIP
#       branch_method:          standard
#       ...                     ...
#       tracking_id:            hdl:21.14100/6e53fa0f-d0cf-4fda-a233-1cf4009ef52c
#       variable_id:            tas
#       variant_info:           1 percent per year decrease in CO2 (immediately a...
#       variant_label:          r1i1p1f1
#       history:                Fri Aug 04 16:36:30 2023: cdo -remapbil,r180x90 N...
#       CDO:                    Climate Data Operators version 2.0.5 (https://mpi...,
#   'piControl': <xarray.Dataset> Size: 933MB
#   Dimensions:    (time: 14400, bnds: 2, lon: 180, lat: 90)
#   Coordinates:
#     * time       (time) object 115kB 0001-01-15 12:00:00 ... 1200-12-15 12:00:00
#     * lon        (lon) float64 1kB 0.0 2.0 4.0 6.0 8.0 ... 352.0 354.0 356.0 358.0
#     * lat        (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#   Dimensions without coordinates: bnds
#   Data variables:
#       time_bnds  (time, bnds) object 230kB ...
#       tas        (time, lat, lon) float32 933MB ...
#   Attributes: (12/44)
#       CDI:                    Climate Data Interface version 2.0.5 (https://mpi...
#       source:                 CESM2 (2017): atmosphere: CAM6 (0.9x1.25 finite v...
#       institution:            National Center for Atmospheric Research, Climate...
#       Conventions:            CF-1.7 CMIP-6.2
#       activity_id:            CMIP
#       case_id:                3
#       ...                     ...
#       variant_label:          r1i1p1f1
#       branch_time_in_parent:  48545.0
#       branch_time_in_child:   0.0
#       branch_method:          standard
#       history:                Tue Aug 22 11:08:48 2023: cdo remapbil,r180x90 NC...
#       CDO:                    Climate Data Operators version 2.0.5 (https://mpi...},
#  'CNRM-ESM2-1': {'1pctCO2': <xarray.Dataset> Size: 117MB
#   Dimensions:    (time: 1800, bnds: 2, lon: 180, lat: 90)
#   Coordinates:
#     * time       (time) datetime64[ns] 14kB 1850-01-16T12:00:00 ... 1999-12-16T...
#     * lon        (lon) float64 1kB 0.0 2.0 4.0 6.0 8.0 ... 352.0 354.0 356.0 358.0
#     * lat        (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#   Dimensions without coordinates: bnds
#   Data variables:
#       time_bnds  (time, bnds) datetime64[ns] 29kB ...
#       tas        (time, lat, lon) float32 117MB ...
#   Attributes: (12/54)
#       CDI:                    Climate Data Interface version 2.0.5 (https://mpi...
#       source:                 CNRM-ESM2-1 (2017):  aerosol: TACTIC_v2 atmos: Ar...
#       institution:            CNRM (Centre National de Recherches Meteorologiqu...
#       Conventions:            CF-1.7 CMIP-6.2
#       creation_date:          2018-06-10T21:57:05Z
#       description:            DECK: 1pctCO2
#       ...                     ...
#       xios_commit:            1442-shuffle
#       nemo_gelato_commit:     49095b3accd5d4c_6524fe19b00467a
#       arpege_minor_version:   6.3.2
#       tracking_id:            hdl:21.14100/7f77190b-5149-44b2-b673-ff735f023b2f
#       history:                Tue Aug 22 15:57:47 2023: cdo remapbil,r180x90 CN...
#       CDO:                    Climate Data Operators version 2.0.5 (https://mpi...,
#   '1pctCO2-cdr': <xarray.Dataset> Size: 156MB
#   Dimensions:    (time: 2400, bnds: 2, lon: 180, lat: 90)
#   Coordinates:
#     * time       (time) datetime64[ns] 19kB 1990-01-16T12:00:00 ... 2189-12-16T...
#     * lon        (lon) float64 1kB 0.0 2.0 4.0 6.0 8.0 ... 352.0 354.0 356.0 358.0
#     * lat        (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#   Dimensions without coordinates: bnds
#   Data variables:
#       time_bnds  (time, bnds) datetime64[ns] 38kB ...
#       tas        (time, lat, lon) float32 156MB ...
#   Attributes: (12/54)
#       CDI:                    Climate Data Interface version 2.0.5 (https://mpi...
#       source:                 CNRM-ESM2-1 (2017):  aerosol: TACTIC_v2 atmos: Ar...
#       institution:            CNRM (Centre National de Recherches Meteorologiqu...
#       Conventions:            CF-1.7 CMIP-6.2
#       creation_date:          2018-12-14T18:38:18Z
#       contact:                contact.cmip@meteo.fr
#       ...                     ...
#       parent_experiment_id:   1pctCO2
#       parent_activity_id:     CMIP
#       experiment:             1 percent per year decrease in CO2 from 4xCO2
#       history:                Tue Aug 22 16:01:23 2023: cdo remapbil,r180x90 CN...
#       tracking_id:            hdl:21.14100/8b344f5f-1278-4e02-90de-bcd1bf5c14df
#       CDO:                    Climate Data Operators version 2.0.5 (https://mpi...,
#   'piControl': <xarray.Dataset> Size: 389MB
#   Dimensions:      (time: 6000, lon: 180, lat: 90, bnds: 2)
#   Coordinates:
#     * time         (time) object 48kB 0271-01-16 12:00:00 ... 0770-12-16 12:00:00
#     * lon          (lon) float64 1kB 0.0 2.0 4.0 6.0 ... 352.0 354.0 356.0 358.0
#     * lat          (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#   Dimensions without coordinates: bnds
#   Data variables:
#       time_bounds  (time, bnds) object 96kB ...
#       tas          (time, lat, lon) float32 389MB ...
#   Attributes: (12/55)
#       CDI:                    Climate Data Interface version 2.0.5 (https://mpi...
#       source:                 CNRM-ESM2-1 (2017):  aerosol: TACTIC_v2 atmos: Ar...
#       institution:            CNRM (Centre National de Recherches Meteorologiqu...
#       Conventions:            CF-1.7 CMIP-6.2
#       creation_date:          2018-04-23T09:02:21Z
#       description:            DECK: control
#       ...                     ...
#       xios_commit:            1442-shuffle
#       nemo_gelato_commit:     49095b3accd5d4c_6524fe19b00467a
#       arpege_minor_version:   6.3.1
#       history:                Wed Aug 23 11:01:28 2023: cdo remapbil,r180x90 CN...
#       tracking_id:            hdl:21.14100/b693d574-e3a4-4935-87b0-b4d8030c1183
#       CDO:                    Climate Data Operators version 2.0.5 (https://mpi...},
#  'GFDL-ESM4': {'1pctCO2': <xarray.Dataset> Size: 117MB
#   Dimensions:    (time: 1800, bnds: 2, lon: 180, lat: 90)
#   Coordinates:
#     * time       (time) object 14kB 0001-01-16 12:00:00 ... 0150-12-16 12:00:00
#     * lon        (lon) float64 1kB 0.0 2.0 4.0 6.0 8.0 ... 352.0 354.0 356.0 358.0
#     * lat        (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#   Dimensions without coordinates: bnds
#   Data variables:
#       time_bnds  (time, bnds) object 29kB ...
#       tas        (time, lat, lon) float32 117MB ...
#   Attributes: (12/48)
#       CDI:                    Climate Data Interface version 2.0.5 (https://mpi...
#       source:                 GFDL-ESM4 (2018):\natmos: GFDL-AM4.1 (Cubed-spher...
#       institution:            National Oceanic and Atmospheric Administration, ...
#       Conventions:            CF-1.7 CMIP-6.0 UGRID-1.0
#       external_variables:     areacella
#       history:                Fri Aug 04 16:34:25 2023: cdo -remapbil,r180x90 N...
#       ...                     ...
#       tracking_id:            hdl:21.14100/12fa27c9-d2f1-41d0-8aba-e043e288fbf9
#       variable_id:            tas
#       variant_info:           N/A
#       references:             see further_info_url attribute
#       variant_label:          r1i1p1f1
#       CDO:                    Climate Data Operators version 2.0.5 (https://mpi...,
#   '1pctCO2-cdr': <xarray.Dataset> Size: 156MB
#   Dimensions:    (time: 2400, bnds: 2, lon: 180, lat: 90)
#   Coordinates:
#     * time       (time) object 19kB 0141-01-16 12:00:00 ... 0340-12-16 12:00:00
#     * lon        (lon) float64 1kB 0.0 2.0 4.0 6.0 8.0 ... 352.0 354.0 356.0 358.0
#     * lat        (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#   Dimensions without coordinates: bnds
#   Data variables:
#       time_bnds  (time, bnds) object 38kB ...
#       tas        (time, lat, lon) float32 156MB ...
#   Attributes: (12/48)
#       CDI:                    Climate Data Interface version 2.0.5 (https://mpi...
#       source:                 GFDL-ESM4 (2018):\natmos: GFDL-AM4.1 (Cubed-spher...
#       institution:            National Oceanic and Atmospheric Administration, ...
#       Conventions:            CF-1.7 CMIP-6.0 UGRID-1.0
#       external_variables:     areacella
#       history:                Fri Aug 04 16:36:44 2023: cdo -remapbil,r180x90 N...
#       ...                     ...
#       tracking_id:            hdl:21.14100/ff953fb3-6a8a-4104-8766-18e43e4434e3
#       variable_id:            tas
#       variant_info:           N/A
#       references:             see further_info_url attribute
#       variant_label:          r1i1p1f1
#       CDO:                    Climate Data Operators version 2.0.5 (https://mpi...,
#   'piControl': <xarray.Dataset> Size: 389MB
#   Dimensions:    (time: 6000, bnds: 2, lon: 180, lat: 90)
#   Coordinates:
#     * time       (time) object 48kB 0001-01-16 12:00:00 ... 0500-12-16 12:00:00
#     * lon        (lon) float64 1kB 0.0 2.0 4.0 6.0 8.0 ... 352.0 354.0 356.0 358.0
#     * lat        (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#   Dimensions without coordinates: bnds
#   Data variables:
#       time_bnds  (time, bnds) object 96kB ...
#       tas        (time, lat, lon) float32 389MB ...
#   Attributes: (12/48)
#       CDI:                    Climate Data Interface version 2.0.5 (https://mpi...
#       source:                 GFDL-ESM4 (2018):\natmos: GFDL-AM4.1 (Cubed-spher...
#       institution:            National Oceanic and Atmospheric Administration, ...
#       Conventions:            CF-1.7 CMIP-6.0 UGRID-1.0
#       external_variables:     areacella
#       history:                Tue Aug 22 11:09:19 2023: cdo remapbil,r180x90 NO...
#       ...                     ...
#       tracking_id:            hdl:21.14100/d4a34d1f-0e7c-489b-9193-8204e7da8ce2
#       variable_id:            tas
#       variant_info:           N/A
#       references:             see further_info_url attribute
#       variant_label:          r1i1p1f1
#       CDO:                    Climate Data Operators version 2.0.5 (https://mpi...},
#  'MIROC-ES2L': {'1pctCO2': <xarray.Dataset> Size: 117MB
#   Dimensions:    (time: 1800, bnds: 2, lon: 180, lat: 90)
#   Coordinates:
#     * time       (time) datetime64[ns] 14kB 1850-01-16T12:00:00 ... 1999-12-16T...
#     * lon        (lon) float64 1kB 0.0 2.0 4.0 6.0 8.0 ... 352.0 354.0 356.0 358.0
#     * lat        (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#   Dimensions without coordinates: bnds
#   Data variables:
#       time_bnds  (time, bnds) datetime64[ns] 29kB ...
#       tas        (time, lat, lon) float32 117MB ...
#   Attributes: (12/46)
#       CDI:                    Climate Data Interface version 2.0.5 (https://mpi...
#       source:                 MIROC-ES2L (2018): \naerosol: SPRINTARS6.0\natmos...
#       institution:            JAMSTEC (Japan Agency for Marine-Earth Science an...
#       Conventions:            CF-1.7 CMIP-6.2
#       activity_id:            CMIP
#       branch_method:          standard
#       ...                     ...
#       variable_id:            tas
#       variant_label:          r1i1p1f2
#       license:                CMIP6 model data produced by MIROC is licensed un...
#       cmor_version:           3.3.2
#       tracking_id:            hdl:21.14100/ed3976f1-f106-42de-9cf2-1474d1947cdb
#       CDO:                    Climate Data Operators version 2.0.5 (https://mpi...,
#   '1pctCO2-cdr': <xarray.Dataset> Size: 391MB
#   Dimensions:    (time: 6024, bnds: 2, lon: 180, lat: 90)
#   Coordinates:
#     * time       (time) object 48kB 0241-01-16 12:00:00 ... 0742-12-16 12:00:00
#     * lon        (lon) float64 1kB 0.0 2.0 4.0 6.0 8.0 ... 352.0 354.0 356.0 358.0
#     * lat        (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#   Dimensions without coordinates: bnds
#   Data variables:
#       time_bnds  (time, bnds) object 96kB ...
#       tas        (time, lat, lon) float32 390MB ...
#   Attributes: (12/46)
#       CDI:                    Climate Data Interface version 2.0.5 (https://mpi...
#       source:                 MIROC-ES2L (2018): \naerosol: SPRINTARS6.0\natmos...
#       institution:            JAMSTEC (Japan Agency for Marine-Earth Science an...
#       Conventions:            CF-1.7 CMIP-6.2
#       activity_id:            CDRMIP
#       branch_method:          standard
#       ...                     ...
#       variable_id:            tas
#       variant_label:          r1i1p1f2
#       license:                CMIP6 model data produced by MIROC is licensed un...
#       cmor_version:           3.3.2
#       tracking_id:            hdl:21.14100/3c770cc6-b63f-4ad0-a09f-56ca60e85488
#       CDO:                    Climate Data Operators version 2.0.5 (https://mpi...,
#   'piControl': <xarray.Dataset> Size: 389MB
#   Dimensions:    (time: 6000, bnds: 2, lon: 180, lat: 90)
#   Coordinates:
#     * time       (time) object 48kB 0271-01-16 12:00:00 ... 0770-12-16 12:00:00
#     * lon        (lon) float64 1kB 0.0 2.0 4.0 6.0 8.0 ... 352.0 354.0 356.0 358.0
#     * lat        (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#   Dimensions without coordinates: bnds
#   Data variables:
#       time_bnds  (time, bnds) object 96kB ...
#       tas        (time, lat, lon) float32 389MB ...
#   Attributes: (12/46)
#       CDI:                    Climate Data Interface version 2.0.5 (https://mpi...
#       source:                 MIROC-ES2L (2018): \naerosol: SPRINTARS6.0\natmos...
#       institution:            JAMSTEC (Japan Agency for Marine-Earth Science an...
#       Conventions:            CF-1.7 CMIP-6.2
#       activity_id:            CMIP
#       branch_method:          standard
#       ...                     ...
#       variable_id:            tas
#       variant_label:          r1i1p1f2
#       license:                CMIP6 model data produced by MIROC is licensed un...
#       cmor_version:           3.3.2
#       tracking_id:            hdl:21.14100/7d717ae8-4aaa-4370-bb1b-30c3a28374e1
#       CDO:                    Climate Data Operators version 2.0.5 (https://mpi...},
#  'NorESM2-LM': {'1pctCO2': <xarray.Dataset> Size: 117MB
#   Dimensions:    (time: 1800, bnds: 2, lon: 180, lat: 90)
#   Coordinates:
#     * time       (time) object 14kB 0001-01-16 12:00:00 ... 0150-12-16 12:00:00
#     * lon        (lon) float64 1kB 0.0 2.0 4.0 6.0 8.0 ... 352.0 354.0 356.0 358.0
#     * lat        (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#   Dimensions without coordinates: bnds
#   Data variables:
#       time_bnds  (time, bnds) object 29kB ...
#       tas        (time, lat, lon) float32 117MB ...
#   Attributes: (12/51)
#       CDI:                       Climate Data Interface version 2.0.5 (https://...
#       source:                    NorESM2-LM (2017): \naerosol: OsloAero\natmos:...
#       institution:               NorESM Climate modeling Consortium consisting ...
#       Conventions:               CF-1.7 CMIP-6.2
#       activity_id:               CMIP
#       branch_method:             Hybrid-restart from year 1600-01-01 of piControl
#       ...                        ...
#       variable_id:               tas
#       variant_label:             r1i1p1f1
#       license:                   CMIP6 model data produced by NCC is licensed u...
#       cmor_version:              3.5.0
#       tracking_id:               hdl:21.14100/25950369-792f-40d9-a573-abb37e9ad8ec
#       CDO:                       Climate Data Operators version 2.0.5 (https://...,
#   '1pctCO2-cdr': <xarray.Dataset> Size: 201MB
#   Dimensions:    (time: 3108, bnds: 2, lon: 180, lat: 90)
#   Coordinates:
#     * time       (time) object 25kB 0141-01-16 12:00:00 ... 0399-12-16 12:00:00
#     * lon        (lon) float64 1kB 0.0 2.0 4.0 6.0 8.0 ... 352.0 354.0 356.0 358.0
#     * lat        (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#   Dimensions without coordinates: bnds
#   Data variables:
#       time_bnds  (time, bnds) object 50kB ...
#       tas        (time, lat, lon) float32 201MB ...
#   Attributes: (12/51)
#       CDI:                       Climate Data Interface version 2.0.5 (https://...
#       source:                    NorESM2-LM (2017): \naerosol: OsloAero\natmos:...
#       institution:               NorESM Climate modeling Consortium consisting ...
#       Conventions:               CF-1.7 CMIP-6.2
#       activity_id:               CDRMIP
#       branch_method:             Branch-restart from year 0141-01-01 of 1pctCO2
#       ...                        ...
#       variable_id:               tas
#       variant_label:             r1i1p1f1
#       license:                   CMIP6 model data produced by NCC is licensed u...
#       cmor_version:              3.5.0
#       tracking_id:               hdl:21.14100/dcf32430-6cc8-4b38-ac53-ab19edd2fba2
#       CDO:                       Climate Data Operators version 2.0.5 (https://...,
#   'piControl': <xarray.Dataset> Size: 194MB
#   Dimensions:    (time: 3000, bnds: 2, lon: 180, lat: 90)
#   Coordinates:
#     * time       (time) object 24kB 1851-01-16 12:00:00 ... 2100-12-16 12:00:00
#     * lon        (lon) float64 1kB 0.0 2.0 4.0 6.0 8.0 ... 352.0 354.0 356.0 358.0
#     * lat        (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#   Dimensions without coordinates: bnds
#   Data variables:
#       time_bnds  (time, bnds) object 48kB ...
#       tas        (time, lat, lon) float32 194MB ...
#   Attributes: (12/51)
#       CDI:                       Climate Data Interface version 2.0.5 (https://...
#       source:                    NorESM2-LM (2017): \naerosol: OsloAero\natmos:...
#       institution:               NorESM Climate modeling Consortium consisting ...
#       Conventions:               CF-1.7 CMIP-6.2
#       activity_id:               CMIP
#       branch_method:             Hybrid-restart from year 1851-01-01 of piControl
#       ...                        ...
#       variable_id:               tas
#       variant_label:             r1i1p1f1
#       license:                   CMIP6 model data produced by NCC is licensed u...
#       cmor_version:              3.5.0
#       tracking_id:               hdl:21.14100/94c0c85e-ac2b-49c1-86d8-80e23ae1fbdc
#       CDO:                       Climate Data Operators version 2.0.5 (https://...},
#  'UKESM1-0-LL': {'1pctCO2': <xarray.Dataset> Size: 117MB
#   Dimensions:    (time: 1800, bnds: 2, lon: 180, lat: 90)
#   Coordinates:
#     * time       (time) object 14kB 1850-01-16 00:00:00 ... 1999-12-16 00:00:00
#     * lon        (lon) float64 1kB 0.0 2.0 4.0 6.0 8.0 ... 352.0 354.0 356.0 358.0
#     * lat        (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#   Dimensions without coordinates: bnds
#   Data variables:
#       time_bnds  (time, bnds) object 29kB ...
#       tas        (time, lat, lon) float32 117MB ...
#   Attributes: (12/48)
#       CDI:                    Climate Data Interface version 2.0.5 (https://mpi...
#       source:                 UKESM1.0-LL (2018): \naerosol: UKCA-GLOMAP-mode\n...
#       institution:            Met Office Hadley Centre, Fitzroy Road, Exeter, D...
#       Conventions:            CF-1.7 CMIP-6.2
#       activity_id:            CMIP
#       branch_method:          standard
#       ...                     ...
#       variable_id:            tas
#       variant_label:          r1i1p1f2
#       license:                CMIP6 model data produced by the Met Office Hadle...
#       cmor_version:           3.4.0
#       tracking_id:            hdl:21.14100/c55cde7a-9f41-478c-92c0-83407d21f046
#       CDO:                    Climate Data Operators version 2.0.5 (https://mpi...,
#   '1pctCO2-cdr': <xarray.Dataset> Size: 506MB
#   Dimensions:    (time: 7800, bnds: 2, lon: 180, lat: 90)
#   Coordinates:
#     * time       (time) object 62kB 1990-01-16 00:00:00 ... 2639-12-16 00:00:00
#     * lon        (lon) float64 1kB 0.0 2.0 4.0 6.0 8.0 ... 352.0 354.0 356.0 358.0
#     * lat        (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#   Dimensions without coordinates: bnds
#   Data variables:
#       time_bnds  (time, bnds) object 125kB ...
#       tas        (time, lat, lon) float32 505MB ...
#   Attributes: (12/49)
#       CDI:                    Climate Data Interface version 2.0.5 (https://mpi...
#       source:                 UKESM1.0-LL (2018): \naerosol: UKCA-GLOMAP-mode\n...
#       institution:            Met Office Hadley Centre, Fitzroy Road, Exeter, D...
#       Conventions:            CF-1.7 CMIP-6.2
#       activity_id:            CDRMIP
#       branch_method:          standard
#       ...                     ...
#       variable_name:          tas
#       variant_label:          r1i1p1f2
#       license:                CMIP6 model data produced by the Met Office Hadle...
#       cmor_version:           3.4.0
#       tracking_id:            hdl:21.14100/f8d57284-c807-4431-9489-630a07dd45dd
#       CDO:                    Climate Data Operators version 2.0.5 (https://mpi...,
#   'piControl': <xarray.Dataset> Size: 1GB
#   Dimensions:    (time: 22560, bnds: 2, lon: 180, lat: 90)
#   Coordinates:
#     * time       (time) object 180kB 1960-01-16 00:00:00 ... 3839-12-16 00:00:00
#     * lon        (lon) float64 1kB 0.0 2.0 4.0 6.0 8.0 ... 352.0 354.0 356.0 358.0
#     * lat        (lat) float64 720B -89.0 -87.0 -85.0 -83.0 ... 85.0 87.0 89.0
#   Dimensions without coordinates: bnds
#   Data variables:
#       time_bnds  (time, bnds) object 361kB ...
#       tas        (time, lat, lon) float32 1GB ...
#   Attributes: (12/48)
#       CDI:                    Climate Data Interface version 2.0.5 (https://mpi...
#       source:                 UKESM1.0-LL (2018): \naerosol: UKCA-GLOMAP-mode\n...
#       institution:            Met Office Hadley Centre, Fitzroy Road, Exeter, D...
#       Conventions:            CF-1.7 CMIP-6.2
#       activity_id:            CMIP
#       branch_method:          standard
#       ...                     ...
#       variable_id:            tas
#       variant_label:          r1i1p1f2
#       license:                CMIP6 model data produced by the Met Office Hadle...
#       cmor_version:           3.4.0
#       tracking_id:            hdl:21.14100/7c0131d5-0189-4856-94a7-a305e139602a
#       CDO:                    Climate Data Operators version 2.0.5 (https://mpi...}}
